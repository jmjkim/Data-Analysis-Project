# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# IBM's Professional Data Analyst (IBM DA0100 Data Analytics Basics for Everyone)

pd.set_option("display.max_columns", None)

csv = pd.read_csv("Final Assignment.csv")
df = pd.DataFrame(csv)

# Product Category = Designer Clothes
dc = df["Product Category"] == "Designer Clothes"
dc_table = df[dc]

plt.figure(figsize = (12, 8))
plt.setp(plt.bar(dc_table["Month-Year of Purchase"], dc_table["Units Sold"]), color = "orange", width = 0.4)

# Product Category = Fitness Gadgets
fg = df["Product Category"] == "Fitness Gadgets"
fg_table = df[fg]

plt.figure(figsize = (12, 8))
plt.setp(plt.bar(fg_table["Month-Year of Purchase"], fg_table["Units Sold"]), color = "blue", width = 0.4)

# Product Category = Travel Accessories
ta = df["Product Category"] == "Travel Accessories"
ta_table = df[ta]

plt.figure(figsize = (12, 8))
plt.setp(plt.bar(ta_table["Month-Year of Purchase"], ta_table["Units Sold"]), color = "green", width = 0.4)

# Product Category = Flat Screen
fs = df["Product Category"] == "Flat Screen"
fs_table = df[fs]

# Concatenate product category tables into one table
tables = [dc_table, fg_table, ta_table, fs_table]
table = pd.concat(tables, keys = ["DC", "FG", "TA", "FS"])

display(table)
# Out:
#       Month-Year of Purchase    Product Category  Units Sold Discount  \
# DC 0            Jan-Mar 2018    Designer Clothes        1275       0%
#    3            Apr-Jun 2018    Designer Clothes        1825       0%
#    6            Jul-Sep 2018    Designer Clothes        3150      10%
#    9            Oct-Dec 2018    Designer Clothes        4715      20%
#    13           Jan-Mar 2019    Designer Clothes        1375       0%
#    16           Apr-Jun 2019    Designer Clothes        2175       0%
#    20           Jul-Sep 2019    Designer Clothes        3100      15%
#    23           Oct-Dec 2019    Designer Clothes        6425      25%
# FG 1            Jan-Mar 2018     Fitness Gadgets        4250      15%
#    4            Apr-Jun 2018     Fitness Gadgets        3760       0%
#    7            Jul-Sep 2018     Fitness Gadgets        1330       0%
#    10           Oct-Dec 2018     Fitness Gadgets        6450      20%
#    11           Oct-Dec 2018     Fitness Gadgets        6450      20%
#    14           Jan-Mar 2019     Fitness Gadgets        1765       0%
#    17           Apr-Jun 2019     Fitness Gadgets        1925       0%
#    21           Jul-Sep 2019     Fitness Gadgets        2530       0%
#    24           Oct-Dec 2019     Fitness Gadgets        7125      20%
# TA 2            Jan-Mar 2018  Travel Accessories        1670       0%
#    5            Apr-Jun 2018  Travel Accessories        1720       0%
#    8            Jul-Sep 2018  Travel Accessories        3550       0%
#    12           Oct-Dec 2018  Travel Accessories        5430      20%
#    15           Jan-Mar 2019  Travel Accessories        1475       0%
#    18           Apr-Jun 2019  Travel Accessories        1215       0%
#    22           Jul-Sep 2019  Travel Accessories        3275       0%
#    25           Oct-Dec 2019  Travel Accessories        6510      30%
# FS 19           Apr-Jun 2018         Flat Screen        4750       0%
#
#       Targeted Campaign  Customer Ratings  Defects Reported
# DC 0                  N               9.6                12
#    3                  N               8.9                23
#    6                  Y               9.3                15
#    9                  Y               7.1                48
#    13                 N               8.6                 6
#    16                 Y               8.8                 8
#    20                 N               9.2                14
#    23                 Y               9.3                12
# FG 1                  N               9.5                12
#    4                  N               7.7                32
#    7                  N               8.5                 8
#    10                 Y               8.7                22
#    11                 Y               8.7                22
#    14                 N               8.9                 5
#    17                 N               8.6                 8
#    21                 N               8.7                12
#    24                 Y               9.6                16
# TA 2                  N               9.3                 8
#    5                  N               9.1                 7
#    8                  Y               9.1                12
#    12                 N               9.2                 9
#    15                 N               7.9                23
#    18                 N               8.2                 6
#    22                 Y               8.7                13
#    25                 Y               9.3                 8
# FS 19                 Y               7.8                34
